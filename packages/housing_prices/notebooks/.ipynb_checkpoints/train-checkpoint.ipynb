# %%
from housing_prices.model import *
from housing_prices.config import load_config

# %%
feature_config = load_config()
model = HousingPricesModel(feature_config)
model.pipeline
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(force_int_remainder_cols=False,
#                                    remainder='passthrough',
#                                    transformers=[('Categorical Preprocessor',
#                                                   Pipeline(steps=[('functiontransformer',
#                                                                    FunctionTransformer(func=<function HousingPricesModel.create_replace_c_all_transformer.<locals>.replace_c_all at 0x10ee67ba0>)),
#                                                                   ('onehotencoder',
#                                                                    OneHotEncoder(cate...
#                                                    'OverallQual', 'OverallCond',
#                                                    'ExterQual', 'ExterCond',
#                                                    'BsmtQual', 'BsmtCond',
#                                                    'BsmtExposure',
#                                                    'BsmtFinType1',
#                                                    'BsmtFinType2', 'HeatingQC',
#                                                    'KitchenQual', 'Functional',
#                                                    'FireplaceQu',
#                                                    'GarageFinish', 'GarageQual',
#                                                    'GarageCond', 'PavedDrive',
#                                                    'PoolQC', 'Fence'])])),
#                 ('knnimputer', KNNImputer(n_neighbors=2)),
#                 ('gradientboostingregressor',
#                  GradientBoostingRegressor(random_state=0))])

# %%
X, y = load_data()
model.pipeline.fit(X, y)
# Out:
# /Users/mknopf/projects/personal/housing-prices/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [5, 8, 13, 14, 18] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(force_int_remainder_cols=False,
#                                    remainder='passthrough',
#                                    transformers=[('Categorical Preprocessor',
#                                                   Pipeline(steps=[('functiontransformer',
#                                                                    FunctionTransformer(func=<function HousingPricesModel.create_replace_c_all_transformer.<locals>.replace_c_all at 0x10ee67ba0>)),
#                                                                   ('onehotencoder',
#                                                                    OneHotEncoder(cate...
#                                                    'OverallQual', 'OverallCond',
#                                                    'ExterQual', 'ExterCond',
#                                                    'BsmtQual', 'BsmtCond',
#                                                    'BsmtExposure',
#                                                    'BsmtFinType1',
#                                                    'BsmtFinType2', 'HeatingQC',
#                                                    'KitchenQual', 'Functional',
#                                                    'FireplaceQu',
#                                                    'GarageFinish', 'GarageQual',
#                                                    'GarageCond', 'PavedDrive',
#                                                    'PoolQC', 'Fence'])])),
#                 ('knnimputer', KNNImputer(n_neighbors=2)),
#                 ('gradientboostingregressor',
#                  GradientBoostingRegressor(random_state=0))])

# %%
model.pipeline.score(X, y)
# Out:
# /Users/mknopf/projects/personal/housing-prices/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [5, 8, 13, 14, 18] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# 0.967595870382804
